# %%
import pandas as pd

# %%
a= {"Name":["hi","hello","bye","tschuss"],
    "Age":[11,12,13,14]}
a=pd.DataFrame(a)
a
# Out:
#       Name  Age
# 0       hi   11
# 1    hello   12
# 2      bye   13
# 3  tschuss   14
